# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Better Buy: Amazon vs. Ulta Beauty
# Sep-26-20 11:19AM
# GameStop Investors Need to Look Beyond the Console Upgrades
# 09:12AM
# What to Know Before You Buy Etsy Stock
# 08:49AM
# Better Buy: MercadoLibre vs. Amazon
# 07:45AM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN', 'Sep-26-20', '11:19AM', 'Better Buy: Amazon vs. Ulta Beauty'],
#  ['AMZN',
#   'Sep-26-20',
#   '09:12AM',
#   'GameStop Investors Need to Look Beyond the Console Upgrades'],
#  ['AMZN', 'Sep-26-20', '08:49AM', 'What to Know Before You Buy Etsy Stock'],
#  ['AMZN', 'Sep-26-20', '07:45AM', 'Better Buy: MercadoLibre vs. Amazon'],
#  ['AMZN',
#   'Sep-26-20',
#   '06:30AM',
#   'We Ask Successful Investors: If You Could Only Own 3 Stocks, What Would They Be?'],
#  ['AMZN', 'Sep-26-20', '04:21AM', 'Point/Counterpoint: The Case for Peloton'],
#  ['AMZN',
#   'Sep-25-20',
#   '08:19PM',
#   'The Stock Market Had a Bad Week. At Least It Wasnt a Terrible One.'],
#  ['AMZN',
#   'Sep-25-20',
#   '08:05PM',
#   'Why Rival Bike Peddlers Could Help Boost Pelotons Stock'],
#  ['AMZN',
#   'Sep-25-20',
#   '04:25PM',
#   'Netflix Inc. stock outperforms market on strong trading day'],
#  ['AMZN',
#   'Sep-25-20',
#   '04:25PM',
#   'Amazon.com Inc. stock rises Friday, outperforms market'],
#  ['AMZN',
#   'Sep-25-20',
#   '04:25PM',
#   '3M Co. stock falls Friday, underperforms market'],
#  ['AMZN', 'Sep-25-20', '04:09PM', 'Market Recap: Friday, September 25'],
#  ['AMZN',
#   'Sep-25-20',
#   '03:33PM',
#   'Tech Companies Wager Billions On Race To Win Over These Consumers'],
#  ['AMZN', 'Sep-25-20', '03:21PM', 'Amazon releases new product offerings'],
#  ['AMZN',
#   'Sep-25-20',
#   '01:25PM',
#   "Wall Street drills Costco stock because it's paying workers $2 more an hour during COVID-19"],
#  ['AMZN',
#   'Sep-25-20',
#   '01:24PM',
#   'Antitrust investigations into Google & Facebook heat up'],
#  ['AMZN',
#   'Sep-25-20',
#   '12:36PM',
#   'This is the great reset of capitalism: TCR Founder & CEO on corporate responsibility'],
#  ['AMZN',
#   'Sep-25-20',
#   '12:30PM',
#   "2 Big Reasons We'll See Even More Streaming Services in 2021"],
#  ['AMZN',
#   'Sep-25-20',
#   '11:49AM',
#   'Why Peloton Interactive Stock Is Running Higher Today'],
#  ['AMZN',
#   'Sep-25-20',
#   '11:42AM',
#   'Stocks on the move: Amazon moves into gaming, Costco reports rise in revenue'],
#  ['AMZN', 'Sep-25-20', '11:37AM', 'Is Spotify Stock a Buy?'],
#  ['AMZN',
#   'Sep-25-20',
#   '10:31AM',
#   "A Look Into Amazon.com's Price Over Earnings"],
#  ['AMZN',
#   'Sep-25-20',
#   '10:30AM',
#   "Why Buy Costco at a Time When Folks Are Thinning Out Portfolios? Here's Why"],
#  ['AMZN',
#   'Sep-25-20',
#   '10:00AM',
#   'Should You Avoid GameStop No Matter How Good the Price?'],
#  ['AMZN',
#   'Sep-25-20',
#   '09:45AM',
#   "Is Amazon Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['AMZN', 'Sep-25-20', '09:31AM', 'Look What Amazon is Unveiling Next'],
#  ['AMZN',
#   'Sep-25-20',
#   '09:19AM',
#   'Microsoft Declares War on Twilio With a New Cloud Service'],
#  ['AMZN',
#   'Sep-25-20',
#   '08:54AM',
#   'FedEx Stock Is on Fire. Wall Street Says Its Still a Buy.'],
#  ['AMZN',
#   'Sep-25-20',
#   '08:05AM',
#   'Palantir Is Going Public. What You Need to Know.'],
#  ['AMZN',
#   'Sep-25-20',
#   '07:55AM',
#   'Amazon Unveiled New Hardware at Its Virtual Product Event. Heres Whats New.'],
#  ['AMZN',
#   'Sep-25-20',
#   '07:30AM',
#   "[video]4 Thoughts on Amazon's Echo, Fire TV and Cloud Gaming Launches"],
#  ['AMZN',
#   'Sep-25-20',
#   '07:15AM',
#   'Got $3,000? Here Are 3 Surefire High-Growth Stocks That Are Just Getting Started'],
#  ['AMZN',
#   'Sep-25-20',
#   '06:00AM',
#   'The #MeToo movement blew up the way Hollywood operates: Jessica Alba'],
#  ['AMZN',
#   'Sep-25-20',
#   '05:35AM',
#   "Amazon's $250 Ring Camera Will Fly Around The House  And Record Everything"],
#  ['AMZN',
#   'Sep-24-20',
#   '10:56PM',
#   'Amazon Launches Luna, a Cloud-Based Video Game Service'],
#  ['AMZN',
#   'Sep-24-20',
#   '09:35PM',
#   "Amazon Joins Fellow Tech Giants In The 'Game Wars' With 'Luna' Launch"],
#  ['AMZN',
#   'Sep-24-20',
#   '08:58PM',
#   "Amazon's Fire TV Gets a Makeover to Better Compete With Roku"],
#  ['AMZN',
#   'Sep-24-20',
#   '07:40PM',
#   'Amazon Chases Google, Microsoft in the Game-Streaming Market'],
#  ['AMZN',
#   'Sep-24-20',
#   '06:48PM',
#   'Apple Buys Startup That Creates Radio-Like Stations for Podcasts'],
#  ['AMZN',
#   'Sep-24-20',
#   '06:16PM',
#   'Deliveroo, Backed by Amazon, Could Launch a 2021 IPO'],
#  ['AMZN',
#   'Sep-24-20',
#   '05:35PM',
#   "'The biggest risk is uncertainty': AllianceBernstein's Valerie Grant on headwinds facing the market ahead of the election"],
#  ['AMZN',
#   'Sep-24-20',
#   '05:30PM',
#   'Dow Jones Futures: Amid Whipsaw Stock Market Action, Tesla, Nvidia, These Tech Titans Hold Key Support'],
#  ['AMZN',
#   'Sep-24-20',
#   '05:21PM',
#   "Microsoft's Xbox boss: Video games undergoing the 'same transformation' as TV and music did"],
#  ['AMZN',
#   'Sep-24-20',
#   '05:17PM',
#   'Amazon Unveils New Echo Lineup, Game Streaming Service, More'],
#  ['AMZN',
#   'Sep-24-20',
#   '05:14PM',
#   'Amazons New Echo Show 10 Features Body-tracking'],
#  ['AMZN',
#   'Sep-24-20',
#   '04:38PM',
#   'Amazon to roll out all-new Echo speakers, gaming streaming service Luna, flying Ring camera'],
#  ['AMZN',
#   'Sep-24-20',
#   '04:36PM',
#   'Amazon Enters Gaming Field; Announces Devices For Home Security, TV'],
#  ['AMZN',
#   'Sep-24-20',
#   '04:25PM',
#   'Netflix Inc. stock rises Thursday, outperforms market'],
#  ['AMZN',
#   'Sep-24-20',
#   '04:25PM',
#   'Amazon.com Inc. stock outperforms market on strong trading day'],
#  ['AMZN',
#   'Sep-24-20',
#   '04:25PM',
#   '3M Co. stock outperforms market on strong trading day'],
#  ['AMZN',
#   'Sep-24-20',
#   '04:22PM',
#   'Microsoft Bolsters Cloud Offerings With Azure, Teams Enhancements'],
#  ['AMZN', 'Sep-24-20', '03:53PM', 'Amazon unveils indoor security drone'],
#  ['AMZN',
#   'Sep-24-20',
#   '03:10PM',
#   'The rotation to more value and cyclical sectors has already begun: Wealth Consulting Group CEO'],
#  ['AMZN', 'Sep-24-20', '02:44PM', 'Why IPOs Are Risky'],
#  ['AMZN',
#   'Sep-24-20',
#   '02:36PM',
#   "Here's everything Amazon announced at its latest hardware event"],
#  ['AMZN',
#   'Sep-24-20',
#   '02:15PM',
#   'Amazon redesigns Fire TV, introduces new Fire TV Stick and low-cost Fire TV Stick Lite'],
#  ['AMZN',
#   'Sep-24-20',
#   '02:13PM',
#   'Amazon Unveils Echo Show 10 With Netflix Streaming, Announces Luna Cloud Gaming Service and More'],
#  ['AMZN',
#   'Sep-24-20',
#   '02:09PM',
#   'Amazon launches Luna cloud gaming service competing with Microsoft and Google'],
#  ['AMZN',
#   'Sep-24-20',
#   '01:57PM',
#   "GRAPHIC-'Healthy correction' or something more? Stock swings keep investors on edge"],
#  ['AMZN',
#   'Sep-24-20',
#   '01:16PM',
#   'Amazon unveils indoor drone and car alarm in security product rollout'],
#  ['AMZN',
#   'Sep-24-20',
#   '01:12PM',
#   'Amazon adds to its lineup of voice-controlled gadgets'],
#  ['AMZN',
#   'Sep-24-20',
#   '01:05PM',
#   "Amazon agreed to call it the 'Prime Bike,' says Echelon CEO"],
#  ['AMZN',
#   'Sep-24-20',
#   '01:02PM',
#   'US STOCKS-Tech stocks lift Wall Street as economic rebound slows'],
#  ['AMZN',
#   'Sep-24-20',
#   '12:23PM',
#   'Alphabet Stock Should Be a Major Winner for the Shelter-In-Place Holidays'],
#  ['AMZN',
#   'Sep-24-20',
#   '11:44AM',
#   'US STOCKS-Nasdaq rises on tech boost as economic recovery cools'],
#  ['AMZN',
#   'Sep-24-20',
#   '11:39AM',
#   'What a Biden presidency would mean for tech stocks'],
#  ['AMZN', 'Sep-24-20', '11:17AM', 'Is Plug Power Stock a Buy?'],
#  ['AMZN',
#   'Sep-24-20',
#   '10:57AM',
#   'Spotify, Hollywood producer Chernin to adapt podcast shows for films, TV'],
#  ['AMZN',
#   'Sep-24-20',
#   '10:53AM',
#   "Echelon CEO responds to controversy of 'prime bike' on Amazon"],
#  ['AMZN',
#   'Sep-24-20',
#   '10:25AM',
#   'US STOCKS-Nasdaq rises on tech boost as economic recovery cools'],
#  ['AMZN',
#   'Sep-24-20',
#   '10:06AM',
#   'Deliveroo Is Said to Start Talks for IPO After Delivery Spike'],
#  ['AMZN', 'Sep-24-20', '09:27AM', 'Is Amazon Stock a Buy?'],
#  ['AMZN', 'Sep-24-20', '09:04AM', 'Are FedEx and UPS Still a Good Value?'],
#  ['AMZN',
#   'Sep-24-20',
#   '08:59AM',
#   'US STOCKS-Wall Street set to open lower as labor market recovery cools'],
#  ['AMZN',
#   'Sep-24-20',
#   '08:50AM',
#   "Tencent's Gaming Business Could Be Trump's Next Target"],
#  ['AMZN',
#   'Sep-24-20',
#   '08:21AM',
#   'Dow Jones Futures: Stock Market Sells Off Bearishly; Tesla Extends Battery Day Dive'],
#  ['AMZN',
#   'Sep-24-20',
#   '08:00AM',
#   '50 Years After Milton Friedman, Companies Wrestle With Wider Purpose'],
#  ['AMZN',
#   'Sep-24-20',
#   '07:18AM',
#   '18 ETFs That Could Help You Send Your Kids to College'],
#  ['AMZN', 'Sep-24-20', '07:15AM', 'Better Hot IPO Stock: Snowflake vs. JFrog'],
#  ['AMZN',
#   'Sep-24-20',
#   '06:06AM',
#   'The FAANG Stock News You Completely Missed Last Month'],
#  ['AMZN',
#   'Sep-23-20',
#   '09:31PM',
#   'China Has a New Richest Person, With Jack Ma Dethroned'],
#  ['AMZN',
#   'Sep-23-20',
#   '06:34PM',
#   'September Sell-Off: S&P 500 Craters 78 Points, Approaching Correction Levels as Apple, Oxy, Lead Tech Stocks, Energy Stocks Down'],
#  ['AMZN', 'Sep-23-20', '05:16PM', 'Amazon Prime Day Begins Oct. 13: Report'],
#  ['AMZN',
#   'Sep-23-20',
#   '04:36PM',
#   'US STOCKS-Wall Street closes lower on fears of a slowing economy'],
#  ['AMZN',
#   'Sep-23-20',
#   '04:25PM',
#   'Netflix Inc. stock falls Wednesday, underperforms market'],
#  ['AMZN',
#   'Sep-23-20',
#   '04:25PM',
#   'Amazon.com Inc. stock falls Wednesday, underperforms market'],
#  ['AMZN',
#   'Sep-23-20',
#   '04:25PM',
#   '3M Co. stock outperforms market despite losses on the day'],
#  ['AMZN',
#   'Sep-23-20',
#   '04:01PM',
#   'Peloton Stock Rises As Amazon Denies Echelon Bike Ties'],
#  ['AMZN',
#   'Sep-23-20',
#   '04:01PM',
#   'US STOCKS-Wall Street closes lower on fears of a slowing economy'],
#  ['AMZN',
#   'Sep-23-20',
#   '03:41PM',
#   'Amazon denies connection to Echelon Fitness Prime Bike'],
#  ['AMZN',
#   'Sep-23-20',
#   '02:52PM',
#   'US STOCKS-Wall Street retreats as business activity slows, raising fears over economy'],
#  ['AMZN',
#   'Sep-23-20',
#   '01:28PM',
#   '7 of the biggest reasons why the stock market is having a dreadful September'],
#  ['AMZN',
#   'Sep-23-20',
#   '01:28PM',
#   "Don't Sweat the Prime Bike Snafu: These 2 Other Recent Amazon Announcements Are Much Bigger Deals"],
#  ['AMZN',
#   'Sep-23-20',
#   '01:15PM',
#   'Amazon tells Echelon to stop selling Prime Bike'],
#  ['AMZN',
#   'Sep-23-20',
#   '01:14PM',
#   'US STOCKS-Wall Street retreats as business activity slows'],
#  ['AMZN',
#   'Sep-23-20',
#   '12:32PM',
#   'Why a president Joe Biden might be great for Tesla stock: analyst'],
#  ['AMZN', 'Sep-23-20', '12:30PM', 'Where Will Amazon Be in 10 Years?'],
#  ['AMZN', 'Sep-23-20', '12:29PM', 'Top Strategists on Where to Invest Now'],
#  ['AMZN',
#   'Sep-23-20',
#   '12:17PM',
#   'The Biggest Retail Takeovers and Mergers of the 2000s and 2010s'],
#  ['AMZN',
#   'Sep-23-20',
#   '12:02PM',
#   'Peloton Shares Rebound After Amazon Denies Echelon Partnership'],
#  ['TSLA',
#   'Sep-26-20',
#   '09:55PM',
#   'Dow Jones Futures: Stock Market Rally, These Leaders Show Bullish Action; How To Game Plan For A Key Week'],
#  ['TSLA',
#   'Sep-26-20',
#   '07:21PM',
#   "Nikola Corp's founder purchased truck designs from third party - FT"],
#  ['TSLA',
#   'Sep-26-20',
#   '05:00PM',
#   'Can Tesla Really Produce A $25,000 Self-Driving Electric Car?'],
#  ['TSLA',
#   'Sep-26-20',
#   '09:00AM',
#   'Secret Sauce Behind Arks Success Is Cathie Woods Diverse Team'],
#  ['TSLA',
#   'Sep-26-20',
#   '07:55AM',
#   'How Tesla, Nikola and Donald Trump are all connected'],
#  ['TSLA',
#   'Sep-26-20',
#   '07:30AM',
#   "Forget Tesla's Battery Day, These EV Stories Are More Important"],
#  ['TSLA',
#   'Sep-25-20',
#   '06:13PM',
#   'Battery Day Devastated Tesla Stock. Why Next Week Could Be Better.'],
#  ['TSLA',
#   'Sep-25-20',
#   '05:14PM',
#   'Stock Market Correction Begins; Tesla Battery Day, Nike Earnings, TikTok Saga In Focus: Weekly Review'],
#  ['TSLA',
#   'Sep-25-20',
#   '04:42PM',
#   'Dow Jones Finishes Week With Strong Gains; This Leaderboard Stock Is In Buy Range'],
#  ['TSLA',
#   'Sep-25-20',
#   '04:25PM',
#   'Tesla Inc. stock outperforms market on strong trading day'],
#  ['TSLA',
#   'Sep-25-20',
#   '03:22PM',
#   "'American public isn't ready' for California's ban on new gas cars: EPA administrator"],
#  ['TSLA',
#   'Sep-25-20',
#   '03:00PM',
#   'Bullish Sentiment Extinguished By Demand Fears'],
#  ['TSLA',
#   'Sep-25-20',
#   '01:39PM',
#   'Nasdaq Soars 150 Points, Fueled By Big Gains For Tesla, Apple, Qualcomm; Boeing Leads Dow Jones'],
#  ['TSLA',
#   'Sep-25-20',
#   '12:58PM',
#   'Dow Jones Up 100 Points After Early Dive; Apple, Microsoft Lead Tech Stock Rally'],
#  ['TSLA',
#   'Sep-25-20',
#   '12:40PM',
#   'Why Lithium Americas Stock Just Popped 16%'],
#  ['TSLA', 'Sep-25-20', '12:26PM', 'Why Tesla Stock Jumped Higher on Friday'],
#  ['TSLA',
#   'Sep-25-20',
#   '12:09PM',
#   'Dow Jones Erases Losses, As Apple, Tesla Jump; Novavax Surges 14% On Coronavirus Vaccine News'],
#  ['TSLA',
#   'Sep-25-20',
#   '11:37AM',
#   'Teslas bumpy road to todays stratospheric stock price'],
#  ['TSLA',
#   'Sep-25-20',
#   '10:21AM',
#   'How Eos Energy Storage is contributing to a lower-carbon future'],
#  ['TSLA',
#   'Sep-25-20',
#   '09:25AM',
#   "Is Tesla Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['TSLA',
#   'Sep-25-20',
#   '08:52AM',
#   'Tesla Releases $2,000 Acceleration Boost Upgrade For AWD Model Y'],
#  ['TSLA',
#   'Sep-25-20',
#   '08:16AM',
#   'Dow Jones Futures Fall: Look For This Bullish Stock Market Signal; Tech Titans Hold Key Support'],
#  ['TSLA',
#   'Sep-25-20',
#   '08:00AM',
#   '2 High-Risk Stocks Robinhood Investors Should Avoid Like the Plague'],
#  ['TSLA',
#   'Sep-25-20',
#   '07:31AM',
#   'The Company Tesla Should Worry About in 2021'],
#  ['TSLA',
#   'Sep-24-20',
#   '08:57PM',
#   'Getting Real About\xa0Electric Cars,\xa0 Batteries and Hype'],
#  ['TSLA',
#   'Sep-24-20',
#   '07:07PM',
#   'Electrified by Tesla, Chinese startups are on the charge'],
#  ['TSLA',
#   'Sep-24-20',
#   '07:02PM',
#   'Electrified by Tesla, Chinese startups are on the charge'],
#  ['TSLA',
#   'Sep-24-20',
#   '07:00PM',
#   'INSIGHT-Electrified by Tesla, Chinese startups are on the charge'],
#  ['TSLA',
#   'Sep-24-20',
#   '05:09PM',
#   'Tesla Readies For Cybertruck With Larger Supercharger Stalls'],
#  ['TSLA',
#   'Sep-24-20',
#   '04:29PM',
#   'Embattled Nikola Gets Its First Sell Rating From Wall Street'],
#  ['TSLA',
#   'Sep-24-20',
#   '04:25PM',
#   'Tesla Inc. stock outperforms competitors on strong trading day'],
#  ['TSLA',
#   'Sep-24-20',
#   '04:22PM',
#   'Dow Jones Finishes Higher After Weak Jobless Claims Report As Tesla Shows This Bullish Chart Action'],
#  ['TSLA',
#   'Sep-24-20',
#   '04:06PM',
#   'EV Charging Station Leader Backed By Top Tesla Investor To Go Public'],
#  ['TSLA',
#   'Sep-24-20',
#   '04:05PM',
#   'Nikola Stock Meltdown Continues As Key Bull On Wall Street Reverses'],
#  ['TSLA',
#   'Sep-24-20',
#   '03:40PM',
#   'INTERVIEW: XL Fleets SPAC Shows that Sales Matter in the $1 Trillion EV Market'],
#  ['TSLA',
#   'Sep-24-20',
#   '03:31PM',
#   'Tesla Accuses Nikola Of Copying Truck Design: Report'],
#  ['TSLA',
#   'Sep-24-20',
#   '03:06PM',
#   'California Is Banning Polluting Cars. Electric-Vehicle Stocks Will Need More Than That.'],
#  ['TSLA',
#   'Sep-24-20',
#   '02:59PM',
#   "Tesla's stock bounces sharply after brief early dip below key technical level"],
#  ['TSLA',
#   'Sep-24-20',
#   '02:57PM',
#   "Why Tesla's Record Vehicle Deliveries Sounds Better Than Analyst Might Think"],
#  ['TSLA',
#   'Sep-24-20',
#   '02:46PM',
#   'DraftKings Is Poised for Hyper-Growth. Why Its Stock Could Be Like Tesla, Amazon, and Netflix.'],
#  ['TSLA',
#   'Sep-24-20',
#   '01:46PM',
#   'Tesla Stock Will Surge 27% to $500, According to This Analyst'],
#  ['TSLA',
#   'Sep-24-20',
#   '01:38PM',
#   'Here are two stocks that stand to benefit from Californias electric-vehicle push'],
#  ['TSLA',
#   'Sep-24-20',
#   '01:35PM',
#   'Dow Jones Roars Back From Big Early Dive As Stocks Shrug Off Jobs Data'],
#  ['TSLA',
#   'Sep-24-20',
#   '01:20PM',
#   'Dow Jones Advances 250 Points, As Apple, Tesla Snap Back; Nikola Plummets 23% On Downgrade'],
#  ['TSLA',
#   'Sep-24-20',
#   '12:32PM',
#   'Disappointed by Teslas Battery Day? The electric-car maker has been winning by playing the long game'],
#  ['TSLA',
#   'Sep-24-20',
#   '12:28PM',
#   "California Governor Gavin Newsom's ban on new gas cars in 2035 may wallop drivers' wallets: analyst"],
#  ['TSLA', 'Sep-24-20', '11:07AM', 'California moves to ban gas-powered cars'],
#  ['TSLA',
#   'Sep-24-20',
#   '11:02AM',
#   'How Far Could Tesla Fall in This Weak Market?'],
#  ['TSLA',
#   'Sep-24-20',
#   '11:00AM',
#   'Look Out Tesla, Volkswagen and the Big Boys Are Coming for You'],
#  ['TSLA',
#   'Sep-24-20',
#   '10:51AM',
#   'Why Tesla Stock Fell Nearly 8% This Morning'],
#  ['TSLA',
#   'Sep-24-20',
#   '10:41AM',
#   "Here's why Tesla's stock tumbled after Battery Day, and why analysts are still bullish"],
#  ['TSLA',
#   'Sep-24-20',
#   '10:00AM',
#   'Is the Market Crashing? 4 Stocks You Can Buy Right Now'],
#  ['TSLA',
#   'Sep-24-20',
#   '09:58AM',
#   'Dow Jones Today, Stocks Rebound Off Opening Lows; Tesla Drags On Nasdaq; Jefferies Financial, Owens & Minor Spike'],
#  ['TSLA',
#   'Sep-24-20',
#   '09:58AM',
#   'Nikola Gets First Sell Rating as Dark Cloud Gathers'],
#  ['TSLA', 'Sep-24-20', '09:45AM', 'Better Buy: Tesla vs. Ford'],
#  ['TSLA',
#   'Sep-24-20',
#   '09:20AM',
#   "Banning Gas-Powered Cars Can't Happen Soon Enough"],
#  ['TSLA',
#   'Sep-24-20',
#   '09:14AM',
#   'Trump: Major carmakers sue US government over China tax'],
#  ['TSLA',
#   'Sep-24-20',
#   '08:59AM',
#   'US STOCKS-Wall Street set to open lower as labor market recovery cools'],
#  ['TSLA',
#   'Sep-24-20',
#   '08:24AM',
#   'CarMax Stock Gains, Nikola Plunges, and the Dow Is Wavering'],
#  ['TSLA',
#   'Sep-24-20',
#   '08:21AM',
#   'Dow Jones Futures: Stock Market Sells Off Bearishly; Tesla Extends Battery Day Dive'],
#  ['TSLA',
#   'Sep-24-20',
#   '07:58AM',
#   'Tesla (TSLA) Falls as Analysts Digest Battery Day'],
#  ['TSLA',
#   'Sep-24-20',
#   '06:36AM',
#   "Nikola's stock tumbles after Wedbush's Ives turns bearish, slashes price target"],
#  ['TSLA',
#   'Sep-24-20',
#   '05:00AM',
#   'Electric vehicle charging network ChargePoint to go public at $2.4 bln valuation'],
#  ['TSLA',
#   'Sep-23-20',
#   '10:46PM',
#   'Volkswagen All-Electric ID.4 SUV To Sell For $40K In US'],
#  ['TSLA',
#   'Sep-23-20',
#   '10:09PM',
#   'Factbox: Tesla could struggle to implement some of its battery advances, experts say'],
#  ['TSLA',
#   'Sep-23-20',
#   '09:31PM',
#   'China Has a New Richest Person, With Jack Ma Dethroned'],
#  ['TSLA',
#   'Sep-23-20',
#   '09:18PM',
#   'Tesla Sues Trump Administration Over Tariffs On Chinese Imports'],
#  ['TSLA',
#   'Sep-23-20',
#   '07:01PM',
#   'Jim Cramer: Tesla, Nike, and a Tale of Expectations'],
#  ['TSLA',
#   'Sep-23-20',
#   '06:29PM',
#   'Why 3 Electric Vehicle Stocks Collapsed Today'],
#  ['TSLA',
#   'Sep-23-20',
#   '06:27PM',
#   "ARK Invest's Tasha Keeney on biggest takeaways from Tesla's battery day"],
#  ['TSLA',
#   'Sep-23-20',
#   '05:52PM',
#   'Tesla is preparing to take over the world with its new batteryjust not yet'],
#  ['TSLA',
#   'Sep-23-20',
#   '05:50PM',
#   'California Just Banned Gas-Powered Car Sales...in 2035'],
#  ['TSLA',
#   'Sep-23-20',
#   '05:46PM',
#   'Tesla could struggle to implement some of its battery advances, experts say'],
#  ['TSLA',
#   'Sep-23-20',
#   '05:40PM',
#   'Tesla Stock Tumbled After Battery Day. Heres What Wall Street Is Saying.'],
#  ['TSLA',
#   'Sep-23-20',
#   '05:11PM',
#   "Tesla's Nevada lithium plan faces stark obstacles on path to production"],
#  ['TSLA',
#   'Sep-23-20',
#   '05:04PM',
#   'SpaceX Starlink Impresses Air Force Weapons Buyer In Big Live-Fire Exercise'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:58PM',
#   'This EV Startup Is Going Public. Unlike Nikola, It Has Sales.'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:53PM',
#   "Tesla's Nevada lithium plan faces stark obstacles on path to production"],
#  ['TSLA',
#   'Sep-23-20',
#   '04:47PM',
#   'Dow Falls 500 Points as Fed Warns More Stimulus Needed'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:42PM',
#   'Dow Jones Sinks Over 500 Points But This Blue Chip Soars On Earnings'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:38PM',
#   "Tesla Disappoints as Nasdaq Falls; Why Zoom's Still Climbing"],
#  ['TSLA',
#   'Sep-23-20',
#   '04:36PM',
#   'US STOCKS-Wall Street closes lower on fears of a slowing economy'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:25PM',
#   'Tesla Inc. stock falls Wednesday, underperforms market'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:21PM',
#   'Tesla Slumps as Battery Day Letdown Clouds $320 Billion Gain'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:15PM',
#   'Tesla Battery Day: No Sizzle, No Beef, But Lots Of Expensive Secret Sauce'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:11PM',
#   "Tesla sues Trump Administration to end tariffs on the 'brain' of its vehicles"],
#  ['TSLA',
#   'Sep-23-20',
#   '04:09PM',
#   'Stock market news live updates: S&P 500 closes at lowest level since July as tech shares fall anew'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:05PM',
#   'Volkswagen Launches Critical EV As California To Ban Gas Cars By 2035'],
#  ['TSLA',
#   'Sep-23-20',
#   '04:01PM',
#   'US STOCKS-Wall Street closes lower on fears of a slowing economy'],
#  ['TSLA',
#   'Sep-23-20',
#   '03:55PM',
#   'Tesla Stock Stumbles and the Rest of the Electric-Vehicle Industry Follows'],
#  ['TSLA',
#   'Sep-23-20',
#   '03:35PM',
#   'The Nikola scandal proves even GM will do anything to catch up to Tesla'],
#  ['TSLA',
#   'Sep-23-20',
#   '03:19PM',
#   'Tesla stock still a buy as uptrend remains intact, chart watcher says'],
#  ['TSLA',
#   'Sep-23-20',
#   '03:17PM',
#   'Dow Jones Drops As Bears Batter Bulls; Apple Stock Surrenders Key Support'],
#  ['TSLA',
#   'Sep-23-20',
#   '02:52PM',
#   'US STOCKS-Wall Street retreats as business activity slows, raising fears over economy'],
#  ['TSLA',
#   'Sep-23-20',
#   '02:30PM',
#   'Dow Jones Dives 400 Points As Selling Ramps Up; Nasdaq Drops Over 2%'],
#  ['TSLA',
#   'Sep-23-20',
#   '02:20PM',
#   'Tesla experienced an hour-long network outage early Wednesday'],
#  ['TSLA',
#   'Sep-23-20',
#   '02:12PM',
#   "Tesla's $25K vehicle would 'bring the brand to the masses': Autoblog Editor-In-Chief"],
#  ['TSLA',
#   'Sep-23-20',
#   '02:04PM',
#   'Why Lithium Miners Like Albemarle, Lithium Americas, and Galaxy Resources Dropped Like Rocks Today'],
#  ['TSLA', 'Sep-23-20', '01:44PM', 'Tesla hit with network outage: RPT'],
#  ['TSLA',
#   'Sep-23-20',
#   '01:30PM',
#   'California to ban sale of new gasoline-powered passenger vehicles in 2035'],
#  ['GOOG',
#   'Sep-26-20',
#   '07:05PM',
#   'Judge rejects bid to delay TikTk U.S. app store ban set for Sunday'],
#  ['GOOG',
#   'Sep-26-20',
#   '05:27PM',
#   'A Right-Leaning Court Will Tackle Some Big Business Cases. The Outcomes Arent Obvious.'],
#  ['GOOG',
#   'Sep-26-20',
#   '12:26PM',
#   "This Week in Apps: Redesigning the iOS 14 home screen, app makers form 'fairness' coalition, latest on TikTok ban"],
#  ['GOOG',
#   'Sep-26-20',
#   '10:49AM',
#   'TikTok Judge Schedules Sunday Hearing as Trumps Ban Looms'],
#  ['GOOG',
#   'Sep-26-20',
#   '08:32AM',
#   'Opinion: Why Mr. Market doesnt care if democracy is collapsing'],
#  ['GOOG',
#   'Sep-26-20',
#   '07:55AM',
#   '3 Cash-Cow Stocks to Buy Ahead of the Next Market Crash'],
#  ['GOOG',
#   'Sep-25-20',
#   '08:05PM',
#   'Why Rival Bike Peddlers Could Help Boost Pelotons Stock'],
#  ['GOOG',
#   'Sep-25-20',
#   '05:56PM',
#   'Google Policy Limits Ads for Election as It Does for Disasters'],
#  ['GOOG',
#   'Sep-25-20',
#   '05:14PM',
#   'Apple Decides to Waive 30% Cut of Paid Events on Facebook, but Only for 3 Months'],
#  ['GOOG',
#   'Sep-25-20',
#   '04:25PM',
#   'Apple Inc. stock outperforms competitors on strong trading day'],
#  ['GOOG',
#   'Sep-25-20',
#   '04:25PM',
#   'Amazon.com Inc. stock rises Friday, outperforms market'],
#  ['GOOG',
#   'Sep-25-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock rises Friday, still underperforms market'],
#  ['GOOG', 'Sep-25-20', '04:09PM', 'Market Recap: Friday, September 25'],
#  ['GOOG',
#   'Sep-25-20',
#   '03:33PM',
#   'Tech Companies Wager Billions On Race To Win Over These Consumers'],
#  ['GOOG',
#   'Sep-25-20',
#   '02:34PM',
#   'Google settles shareholder lawsuits over sexual-harassment scandals'],
#  ['GOOG',
#   'Sep-25-20',
#   '02:14PM',
#   'Republican AG Slams Democrats Who Would Shun DOJs Google Suit'],
#  ['GOOG',
#   'Sep-25-20',
#   '02:12PM',
#   'U.S. judge expected to decide by Sunday if TikTok will remain in U.S. app stores'],
#  ['GOOG',
#   'Sep-25-20',
#   '01:33PM',
#   'Google Reaches $310 Million Settlement In Misconduct Case'],
#  ['GOOG',
#   'Sep-25-20',
#   '01:24PM',
#   'Antitrust investigations into Google & Facebook heat up'],
#  ['GOOG',
#   'Sep-25-20',
#   '01:20PM',
#   'Google to block U.S. election ads after polls close'],
#  ['GOOG', 'Sep-25-20', '01:18PM', 'Google to block election ads after Nov.3'],
#  ['GOOG',
#   'Sep-25-20',
#   '12:55PM',
#   'Alphabet settles shareholder suit over sexual harassment claims'],
#  ['GOOG',
#   'Sep-25-20',
#   '09:45AM',
#   'Google to Increase Push for Apps to Give Cut of In-App Purchases'],
#  ['GOOG',
#   'Sep-25-20',
#   '07:55AM',
#   'Amazon Unveiled New Hardware at Its Virtual Product Event. Heres Whats New.'],
#  ['GOOG',
#   'Sep-25-20',
#   '07:31AM',
#   'The Company Tesla Should Worry About in 2021'],
#  ['GOOG',
#   'Sep-25-20',
#   '07:30AM',
#   "[video]4 Thoughts on Amazon's Echo, Fire TV and Cloud Gaming Launches"],
#  ['GOOG',
#   'Sep-25-20',
#   '06:00AM',
#   'The #MeToo movement blew up the way Hollywood operates: Jessica Alba'],
#  ['GOOG',
#   'Sep-25-20',
#   '12:48AM',
#   'Justice Department asks judge to allow U.S. to bar WeChat from U.S. app stores'],
#  ['GOOG',
#   'Sep-24-20',
#   '11:30PM',
#   'Google Services, Including Gmail, YouTube Disrupted As Servers Crash'],
#  ['GOOG',
#   'Sep-24-20',
#   '11:29PM',
#   'Google, Facebook CEOs Could Face Subpoena From Senate Panel'],
#  ['GOOG',
#   'Sep-24-20',
#   '10:56PM',
#   'Amazon Launches Luna, a Cloud-Based Video Game Service'],
#  ['GOOG',
#   'Sep-24-20',
#   '09:15PM',
#   'Google Meet and other Google services go down (Updated)'],
#  ['GOOG',
#   'Sep-24-20',
#   '07:40PM',
#   'Amazon Chases Google, Microsoft in the Game-Streaming Market'],
#  ['GOOG',
#   'Sep-24-20',
#   '05:21PM',
#   "Microsoft's Xbox boss: Video games undergoing the 'same transformation' as TV and music did"],
#  ['GOOG',
#   'Sep-24-20',
#   '04:56PM',
#   'Alphabet to Help Employees Tackle Student Loans'],
#  ['GOOG',
#   'Sep-24-20',
#   '04:36PM',
#   'PayPal and Square Could Gain as EU Mulls iPhone Payments Rules'],
#  ['GOOG',
#   'Sep-24-20',
#   '04:25PM',
#   'Apple Inc. stock rises Thursday, outperforms market'],
#  ['GOOG',
#   'Sep-24-20',
#   '04:25PM',
#   'Amazon.com Inc. stock outperforms market on strong trading day'],
#  ['GOOG',
#   'Sep-24-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock rises Thursday, outperforms market'],
#  ['GOOG',
#   'Sep-24-20',
#   '04:22PM',
#   'Microsoft Bolsters Cloud Offerings With Azure, Teams Enhancements'],
#  ['GOOG',
#   'Sep-24-20',
#   '04:16PM',
#   'How a U.S. Google Probe Could Shake Up Internet Search'],
#  ['GOOG',
#   'Sep-24-20',
#   '03:10PM',
#   'The rotation to more value and cyclical sectors has already begun: Wealth Consulting Group CEO'],
#  ['GOOG',
#   'Sep-24-20',
#   '02:43PM',
#   'Alphabet, Facebook, Twitter CEOs Asked to Appear at Senate Hearing'],
#  ['GOOG',
#   'Sep-24-20',
#   '02:09PM',
#   'Amazon launches Luna cloud gaming service competing with Microsoft and Google'],
#  ['GOOG',
#   'Sep-24-20',
#   '01:49PM',
#   'Senate panel wants CEOs of Facebook, Google, Twitter to testify Oct. 1: report'],
#  ['GOOG',
#   'Sep-24-20',
#   '01:39PM',
#   'Judge says U.S. must defend or delay TikTok app store ban by Friday'],
#  ['GOOG',
#   'Sep-24-20',
#   '01:12PM',
#   'TikTok Judge Tells U.S. to Delay Ban or Argue for It Friday'],
#  ['GOOG',
#   'Sep-24-20',
#   '12:46PM',
#   'Google, U.S. government prepare for battle over market power'],
#  ['GOOG',
#   'Sep-24-20',
#   '12:23PM',
#   'Alphabet Stock Should Be a Major Winner for the Shelter-In-Place Holidays'],
#  ['GOOG',
#   'Sep-24-20',
#   '12:12PM',
#   'Senate panel plans to issue subpoenas to CEOs of Google, Facebook, Twitter'],
#  ['GOOG',
#   'Sep-24-20',
#   '11:39AM',
#   'What a Biden presidency would mean for tech stocks'],
#  ['GOOG',
#   'Sep-24-20',
#   '10:57AM',
#   'Facebook is a whole different animal and may not be able to exist in its current form under a new regime: expert'],
#  ['GOOG',
#   'Sep-24-20',
#   '10:00AM',
#   'Coronavirus Is Teaching Me What I Cant Do Online'],
#  ['GOOG',
#   'Sep-24-20',
#   '10:00AM',
#   'Tech Veterans Try to Build a Kinder, More Thoughtful Facebook'],
#  ['GOOG', 'Sep-24-20', '08:00AM', 'Apples App Store Isnt Evil'],
#  ['GOOG',
#   'Sep-24-20',
#   '06:45AM',
#   'Spotify, Match Launch Coalition to Protest App Store Rules'],
#  ['GOOG',
#   'Sep-24-20',
#   '06:06AM',
#   'The FAANG Stock News You Completely Missed Last Month'],
#  ['GOOG',
#   'Sep-24-20',
#   '06:00AM',
#   'Influencers with Andy Serwer: Jessica Alba'],
#  ['GOOG',
#   'Sep-24-20',
#   '04:09AM',
#   'Google Maps Adds Feature To Identify COVID-19 Hot Zones'],
#  ['GOOG',
#   'Sep-24-20',
#   '02:35AM',
#   'Thailand takes first legal action against Facebook, Twitter over content'],
#  ['GOOG',
#   'Sep-23-20',
#   '10:27PM',
#   'GoodRx Surges 53% On Trading Debut After $1.1B IPO'],
#  ['GOOG',
#   'Sep-23-20',
#   '10:17PM',
#   'TikTok asks judge to block U.S. from barring app for download'],
#  ['GOOG',
#   'Sep-23-20',
#   '06:24PM',
#   'Barr Remains Wary of Security Concerns in Oracles TikTok Deal'],
#  ['GOOG',
#   'Sep-23-20',
#   '05:26PM',
#   "DOJ's Investigation Of Google 'Important' For Stock, BofA Says"],
#  ['GOOG',
#   'Sep-23-20',
#   '04:25PM',
#   'Apple Inc. stock underperforms Wednesday when compared to competitors'],
#  ['GOOG',
#   'Sep-23-20',
#   '04:25PM',
#   'Amazon.com Inc. stock falls Wednesday, underperforms market'],
#  ['GOOG',
#   'Sep-23-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock falls Wednesday, underperforms market'],
#  ['GOOG',
#   'Sep-23-20',
#   '03:07PM',
#   'TikTok asks judge to block U.S. from barring app for download'],
#  ['GOOG',
#   'Sep-23-20',
#   '02:56PM',
#   'DOJ Petitions Congress to Curb Legal Protections for Internet Companies'],
#  ['GOOG', 'Sep-23-20', '12:33PM', 'Google Maps gets a COVID-19 layer'],
#  ['GOOG', 'Sep-23-20', '12:30PM', 'Where Will Amazon Be in 10 Years?'],
#  ['GOOG',
#   'Sep-23-20',
#   '11:45AM',
#   'Facebook Tool Faulted for Lapses in Finding Voter Misinformation'],
#  ['GOOG',
#   'Sep-23-20',
#   '11:37AM',
#   'Google Antitrust Lawsuit to Narrowly Focus on Search Dominance'],
#  ['GOOG',
#   'Sep-23-20',
#   '10:19AM',
#   "EU's antitrust probe of Google-Fitbit gets more time"],
#  ['GOOG',
#   'Sep-23-20',
#   '09:00AM',
#   'Thailand to start legal action vs Facebook, Google, Twitter over content'],
#  ['GOOG',
#   'Sep-23-20',
#   '08:10AM',
#   'EU regulators extend Google, Fitbit deal probe to Dec. 23'],
#  ['GOOG',
#   'Sep-23-20',
#   '07:28AM',
#   'Is Google-Backed Telemedicine Stock Amwell a Buy After Its IPO?'],
#  ['GOOG',
#   'Sep-23-20',
#   '07:07AM',
#   'A Deep Dive Into JFrog -- the Tech Company Keeping Your Software Updated'],
#  ['GOOG',
#   'Sep-23-20',
#   '06:08AM',
#   'Is This Hot IPO Stock a Better Buy Than Teladoc Health?'],
#  ['GOOG',
#   'Sep-23-20',
#   '05:14AM',
#   'Facebook, Twitter, YouTube Make Peace With Advertisers Over Harmful Content: FT'],
#  ['GOOG',
#   'Sep-23-20',
#   '03:22AM',
#   'Not All FAANG Stocks Are Going To Be Winners, Munster Says'],
#  ['GOOG',
#   'Sep-22-20',
#   '10:29PM',
#   'Blacklisting U.S.\xa0Tech Would Highlight Chinas\xa0Own Weakness'],
#  ['GOOG',
#   'Sep-22-20',
#   '09:15PM',
#   'Capital One and PayPal Veterans Roll Out Next-Generation Banking App'],
#  ['GOOG',
#   'Sep-22-20',
#   '08:20PM',
#   "A $50 Phone is Ambani's Weapon to Dominate India Telecom Market"],
#  ['GOOG',
#   'Sep-22-20',
#   '08:14PM',
#   'Trump to Meet With State Enforcers Before Expected Google Case'],
#  ['GOOG',
#   'Sep-22-20',
#   '07:06PM',
#   'Why Shares of American Well Trounced the Market on Tuesday'],
#  ['GOOG',
#   'Sep-22-20',
#   '06:55PM',
#   "Microsoft Guns for Twilio's Business With Launch of Azure Communication Services"],
#  ['GOOG',
#   'Sep-22-20',
#   '06:14PM',
#   'Daily Crunch: Microsoft launches Azure Communication Services'],
#  ['GOOG',
#   'Sep-22-20',
#   '05:19PM',
#   "'The stocks in the S&P 500 are not necessarily reflective of the full economy': Strategist"],
#  ['GOOG',
#   'Sep-22-20',
#   '04:25PM',
#   'Apple Inc. stock rises Tuesday, still underperforms market'],
#  ['GOOG',
#   'Sep-22-20',
#   '04:25PM',
#   'Amazon.com Inc. stock rises Tuesday, outperforms market'],
#  ['GOOG',
#   'Sep-22-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock rises Tuesday, outperforms market'],
#  ['GOOG',
#   'Sep-22-20',
#   '03:53PM',
#   'How Tesla stacks up against other tech juggernauts at similar stages  theres good news and bad news'],
#  ['GOOG',
#   'Sep-22-20',
#   '03:25PM',
#   'Mnuchin, Powell promise action to aid economic recovery'],
#  ['GOOG',
#   'Sep-22-20',
#   '03:11PM',
#   'Amazon Restricts Ads for Competing Electronic Devices'],
#  ['GOOG', 'Sep-22-20', '03:05PM', 'Top 20 Richest People In The World'],
#  ['GOOG',
#   'Sep-22-20',
#   '01:50PM',
#   '11 Craziest Money-Losing Wall Street Moves in History'],
#  ['GOOG',
#   'Sep-22-20',
#   '01:26PM',
#   'Disney Plus Now Streaming on Google Assistant Smart-Display Devices via Voice Commands'],
#  ['GOOG',
#   'Sep-22-20',
#   '12:32PM',
#   'Alphabet (GOOG) Has Risen 19% in Last One Year, Outperforms Market'],
#  ['GOOG',
#   'Sep-22-20',
#   '12:29PM',
#   'Apple Stock Might Be the Only Thing Standing Between the Market and Another Selloff']]

# %%
import nltk
nltk.downloader.download('vader_lexicon')
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

scores_df
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ravi\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#        neg    neu    pos  compound
# 0    0.000  0.263  0.737    0.8126
# 1    0.000  1.000  0.000    0.0000
# 2    0.000  1.000  0.000    0.0000
# 3    0.000  0.395  0.605    0.5574
# 4    0.000  0.774  0.226    0.5859
# ..     ...    ...    ...       ...
# 295  0.000  0.490  0.510    0.6369
# 296  0.146  0.854  0.000   -0.0516
# 297  0.000  1.000  0.000    0.0000
# 298  0.000  1.000  0.000    0.0000
# 299  0.000  1.000  0.000    0.0000
#
# [300 rows x 4 columns]

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()
